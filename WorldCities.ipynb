# %% [markdown]
# ## Imports and such things

# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from geopy.geocoders import Nominatim
import folium
import requests
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import re

# %% [markdown]
# ## Scrape list of largest cities from Wikipedia

# %% [markdown]
# The wikipedia page [List of largest cities](https://en.wikipedia.org/wiki/List_of_largest_cities) has a list of the largest cities in the world.
# We are interested in table that contains the actual cities, and want the cityname, the nation, and its city proper population.
# In addition, we grab the link to said cities' page, to later scrape more information.
#
# We will first use urllib to fetch the page, then BeautifulSoup to parse it and find the first (and only) sortable table.

# %%
# location of the wikipedia article
url = "https://en.wikipedia.org/wiki/List_of_largest_cities"

# fetch the article
req = urllib.request.urlopen(url)
article = req.read().decode()

# parse with BeautifulSoup and find the first sortable table
soup = BeautifulSoup(article, 'html.parser')
table = soup.find('table', class_='sortable')

# %% [markdown]
# Every row in the table will also have a link to the cities wikipedia page. We will use the following function to scrape specific information from that page.

# %%
# create an empty DataFrame
cols=["City", "Nation", "Population", "URL"]
df_cities = pd.DataFrame(columns=cols)
df_cities['Population'].astype(int)
    
# iterate trough all the rows in the table:
for tr in table.find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue                            # skips first row with headings
    nation = tds[0].find('a').string        # first td column contains nation   
    try:
        pop = int(re.compile(r'\[.*\]').sub("",tds[2].text).replace(',',''))  # rough but working way to parse the population count
    except ValueError:
        pop = 0
    city_a = tr.find('th').find('a')        # the first column contains th tag and contains the <a> link to the city
    city = city_a.string
    url = "https://en.wikipedia.org" + city_a['href']
    df_cities = df_cities.append({
        'City': city, 
        'Nation': nation, 
        'Population': pop, 
        'URL': url
    }, ignore_index=True)

# %%
df_cities.head()
# Out:
#         City                      Nation Population  \
# 0  Chongqing  People's Republic of China   30751600
# 1   Shanghai  People's Republic of China   24256800
# 2      Delhi                       India   11034555
# 3    Beijing  People's Republic of China   21516000
# 4      Dhaka                  Bangladesh   14399000
#
#                                        URL
# 0  https://en.wikipedia.org/wiki/Chongqing
# 1   https://en.wikipedia.org/wiki/Shanghai
# 2      https://en.wikipedia.org/wiki/Delhi
# 3    https://en.wikipedia.org/wiki/Beijing
# 4      https://en.wikipedia.org/wiki/Dhaka

# %% [markdown]
# ## Adding geopositioning data
#
# We can scrape the geoposition coordinates for every city from the respective city page.
# The following function scrape the city page and uses a simple regular expression to capture the coordinates.

# %%
# Scrape an individual cities page for its coordinates
def scrape_city_coords(url):
    req = urllib.request.urlopen(url)
    article = req.read().decode()
    reg = re.search(r'"lat":(.*?),"lon":(.*?)}', article)
    lat = float(reg.group(1))
    lon = float(reg.group(2))
    return lat,lon

# %%
df_cities["Latitude"], df_cities["Longitude"] = zip(*df_cities["URL"].map(scrape_city_coords))

# %%
df_cities.head()
# Out:
#         City                      Nation Population  \
# 0  Chongqing  People's Republic of China   30751600
# 1   Shanghai  People's Republic of China   24256800
# 2      Delhi                       India   11034555
# 3    Beijing  People's Republic of China   21516000
# 4      Dhaka                  Bangladesh   14399000
#
#                                        URL   Latitude   Longitude
# 0  https://en.wikipedia.org/wiki/Chongqing  29.558333  106.566667
# 1   https://en.wikipedia.org/wiki/Shanghai  31.228611  121.474722
# 2      https://en.wikipedia.org/wiki/Delhi  28.610000   77.230000
# 3    https://en.wikipedia.org/wiki/Beijing  39.916667  116.383333
# 4      https://en.wikipedia.org/wiki/Dhaka  23.716111   90.396111

# %% [markdown]
# ## Putting these cities on the map

# %%
# create map of the world using latitude and longitude values
map_world = folium.Map(location=[0,0],zoom_start=2)

# add markers to map
for lat, lng, city, nation, pop in zip(df_cities['Latitude'], df_cities['Longitude'], df_cities['City'], df_cities['Nation'], df_cities['Population']):
    label = '{}, {}: {}'.format(city, nation, pop)
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
    ).add_to(map_world)  
    
map_world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Getting more information from Foursquare

# %% [markdown]
# This information is needed to connect with Foursquare API

# %%
CLIENT_ID = 'YPBVFDUZOP1M24BKCWGXIYZ3RFACOE3V35WSFY4DSCMRU44L' # your Foursquare ID
CLIENT_SECRET = 'VYHYTBSRIZBPYAOCP5ZEFV3YM4C40YEQCQWCUO4NC1JTPNJM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100

# %%
def getRecommendedVenues(cities, latitudes, longitudes):
    
    venues_list=[]
    for city, lat, lon in zip(cities, latitudes, longitudes):
        
        print("city:" + city)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&section=topPicks&client_id={}&client_secret={}&v={}&ll={},{}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lon, 
            5)
            
        # make the GET request
        response = requests.get(url)
        if response.status_code == requests.codes.ok:
            results = response.json()["response"]['groups'][0]['items']
        else:
            print ("status was:" + str(response.status_code))
            print (response)
            continue
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            city,
            lat, 
            lon, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])


    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City',
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
world_venues = getRecommendedVenues(df_cities['City'], df_cities['Latitude'], df_cities['Longitude'])
world_venues.head()
# Out:
# city:Chongqing
# city:Shanghai
# city:Delhi
# city:Beijing
# city:Dhaka
# city:Mumbai
# city:Lagos
# city:Chengdu
# city:Karachi
# city:Guangzhou
# city:Istanbul
# city:Tokyo
# city:Tianjin
# city:Moscow
# city:São Paulo
# city:Kinshasa
# city:Baoding
# city:Lahore
# city:Cairo
# city:Seoul
# city:Jakarta
# city:Wenzhou
# city:Mexico City
# city:Lima
# city:London
# city:Bangkok
# city:Xi'an
# city:Chennai
# city:Bangalore
# city:New York City
# city:Ho Chi Minh City
# city:Hyderabad
# city:Shenzhen
# city:Suzhou
# city:Nanjing
# city:Dongguan
# city:Tehran
# city:Quanzhou
# city:Shenyang
# city:Bogotá
# city:Hong Kong
# city:Baghdad
# city:Fuzhou
# city:Changsha
# city:Wuhan
# city:Hanoi
# city:Rio de Janeiro
# city:Qingdao
# city:Foshan
# city:Zunyi
# city:Santiago
# city:Riyadh
# city:Ahmedabad
# city:Singapore
# city:Shantou
# city:Ankara
# city:Yangon
# city:Saint Petersburg
# city:Sydney
# city:Casablanca
# city:Melbourne
# city:Abidjan
# city:Alexandria
# city:Kolkata
# city:Surat
# city:Johannesburg
# city:Dar es Salaam
# city:Shijiazhuang
# city:Harbin
# city:Giza
# city:İzmir
# city:Zhengzhou
# city:New Taipei City
# city:Los Angeles
# city:Changchun
# city:Cape Town
# city:Yokohama
# city:Khartoum
# city:Guayaquil
# city:Hangzhou
# city:Xiamen
# city:Berlin
# city:Busan
# city:Ningbo
# city:Jeddah
# city:Durban
# city:Algiers
# city:Kabul
# city:Hefei
# city:Mashhad
# city:Pyongyang
# city:Madrid
# city:Faisalabad
# city:Baku
# city:Tangshan
# city:Ekurhuleni
# city:Nairobi
# city:Zhongshan
# city:Pune
# city:Addis Ababa
# city:Jaipur
# city:Buenos Aires
# city:Incheon
# city:Quezon City
# city:Toronto
# city:Kiev
# city:Salvador
# city:Rome
# city:Dubai
# city:Luanda
# city:Lucknow
# city:Kaohsiung
# city:Kanpur
# city:Surabaya
# city:Taichung
# city:Basra
# city:Taipei
# city:Chicago
# city:Osaka
# city:Quito
# city:Chaozhou
# city:Fortaleza
# city:Chittagong
# city:Bandung
# city:Managua
# city:Brasília
# city:Belo Horizonte
# city:Daegu
# city:Houston
# city:Douala
# city:Medellin
# city:Yaoundé
# city:Nagpur
# city:Cali
# city:Tashkent
# city:Nagoya
# city:Isfahan
# city:Phnom Penh
# city:Paris
# city:Ouagadougou
# city:Lanzhou
# city:Kano
# city:Dalian
# city:Guatemala City
# city:Havana
# city:Rawalpindi
# city:Medan
# city:Accra
# city:Visakhapatnam
# city:Gujranwala
# city:Jinan
# city:Karaj
# city:Peshawar
# city:Minsk
# city:Caracas
# city:Sana'a
# city:Sapporo
# city:Tainan
# city:Bucharest
# city:Curitiba
# city:Shiraz
# city:Vienna
# city:Brazzaville
# city:Bhopal
# city:Almaty
# city:Hamburg
# city:Manila
# city:Kuala Lumpur
# city:Maputo
# city:Budapest
# city:Warsaw
# city:Lusaka
# city:Kathmandu
# city:Tabriz
# city:Hyderabad
# city:Palembang
# city:Tijuana
# city:Patna
# city:Montreal
# city:Davao City
# city:Harare
# city:Barcelona
# city:Maracaibo
# city:Caloocan
# city:Philadelphia
# city:Novosibirsk
# city:Phoenix
# city:Oran
# city:Semarang
# city:Recife
# city:Kobe
# city:Daejeon
# city:Kampala
# city:Kawasaki
# city:Guadalajara
# city:Auckland
# city:Vijayawada
# city:Fukuoka
# city:Gwangju
# city:Porto Alegre
# city:Kyoto
# city:San Antonio
# city:Santa Cruz de la Sierra
# city:Munich
# city:Kharkiv
# city:Yekaterinburg
# city:San Diego
# city:Barranquilla
# city:Milan
# city:Ibadan
# city:Makassar
# city:Córdoba
# city:Prague
# city:Mandalay
# city:Dallas
# city:Montevideo
# city:Qom
# city:Ahvaz
# city:Sofia
# city:Nizhny Novgorod
# city:Abuja
# city:Calgary
# city:Saitama
# city:Suwon
# city:Hiroshima
# city:Rosario
# city:Brisbane
# city:Allahabad
# city:Belgrade
# city:Campinas
# city:Ulsan
# city:Omsk
# city:Dakar
# city:Abu Dhabi
# city:Monterrey
# city:Tripoli
# city:Rostov-on-Don
# city:T'bilisi
# city:Fez
# city:Birmingham
# city:Yerevan
# city:Cologne
# city:Tunis
# city:Bulawayo
# city:Astana
# city:Islamabad
# city:Cartagena
#         City   Latitude   Longitude  \
# 0  Chongqing  29.558333  106.566667
# 1  Chongqing  29.558333  106.566667
# 2  Chongqing  29.558333  106.566667
# 3  Chongqing  29.558333  106.566667
# 4  Chongqing  29.558333  106.566667
#
#                                           Venue  Venue Latitude  \
# 0                                       大队长知青火锅       29.581195
# 1  Apple Paradise Walk Chongqing (Apple 重庆北城天街)       29.580996
# 2                                      Paulaner       29.561489
# 3                                Blue Frog (蓝蛙)       29.580209
# 4                         Club Intercontinental       29.561557
#
#    Venue Longitude       Venue Category
# 0       106.529219    Hotpot Restaurant
# 1       106.529746    Electronics Store
# 2       106.532280    German Restaurant
# 3       106.528782  American Restaurant
# 4       106.520209               Lounge

# %% [markdown]
# That's looking pretty awesome. Now let's prevent more scraping by saving the dataframe to a file.

# %%
df_cities.to_csv('cities.csv')
world_venues.to_csv('venues.csv')

# %%
world_venues.describe()
# Out:
#           Latitude    Longitude  Venue Latitude  Venue Longitude
# count  1225.000000  1225.000000     1225.000000      1225.000000
# mean     21.892944    46.496361       21.894071        46.497047
# std      22.451007    71.801368       22.450103        71.801005
# min     -37.813611  -118.250000      -37.815571      -118.250051
# 25%      10.800000     7.483333       10.800865         7.475612
# 50%      27.683333    52.533333       27.690678        52.520820
# 75%      36.300000   113.393000       36.300500       113.380386
# max      59.937500   174.740000       59.939728       174.756709

# %% [markdown]
# ## Putting all venues on a map

# %%
# create map of the world using latitude and longitude values
map_venues = folium.Map(location=[0,0],zoom_start=2)

# add markers to map
for lat, lng, city, venue in zip(world_venues['Venue Latitude'], world_venues['Venue Longitude'], world_venues['City'],  world_venues['Venue']):
    label = '{}: {}'.format(city, venue)
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
    ).add_to(map_venues)  
    
map_venues
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

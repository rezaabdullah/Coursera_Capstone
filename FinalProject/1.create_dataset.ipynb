# %% [markdown]
# # Creating a Dutch Cities dataset

# %% [markdown]
# The wikipedia page [List of largest cities](https://en.wikipedia.org/wiki/List_of_largest_cities) has a list of the largest cities in the world.
# We are interested in table that contains the actual cities, and want the cityname, the nation, and its city proper population.

# %% [markdown]
# In [Section 2](#2.-Scrape-list-of-largest-cities-from-Wikipedia), we use urllib to fetch the page, then BeautifulSoup to parse it and find the first (and only) sortable table.
# We also scrape the URL referencing the individual cities' pages.

# %% [markdown]
# In [Section 3](#3.-Adding-geopositioning-data) we scrape the wikipedia page for every individual city in order to get the cities geographic coordinates.
# In theory we could use this step to grab more information, like population density. However, since we want to demonstrate the use of the Foursquare API, we will not use such data.

# %% [markdown]
# In [Section 4](#4.-Getting-more-information-from-Foursquare) we use the Foursquare API to learn more about these cities.
# Specifically we ask for top recommendations in those cities, to get an idea of what is popular.

# %% [markdown]
# In [Section 5](#5.-Saving-the-dataframes) we export the created dataframe so we can import it in other notebooks.

# %% [markdown]
# ## 1. Imports and such things

# %% [markdown]
# We use the following libraries to fetch and parse html pages, and to interact with the Foursquare API.

# %%
import urllib.request
from bs4 import BeautifulSoup
import requests
import requests_cache

# Request_cache caches all calls to wikipedia and foursquare so we only have to do it once.
requests_cache.install_cache('requests_cache')

# %% [markdown]
# We use regular expressions, e.g. to extract population count and city coordinates from scraped webpages

# %%
import re

# %% [markdown]
# We use Pandas for building the dataframe.

# %%
import pandas as pd

# %% [markdown]
# ## 2. Scrape list of Dutch cities from Wikipedia

# %% [markdown]
# The following code fetches a Wikipedia page.

# %%
# location of the wikipedia article
url = "https://nl.wikipedia.org/wiki/Tabel_van_Nederlandse_gemeenten"

# fetch the article
response = requests.get(url)
article = response.text

# %% [markdown]
# We use BeautifulSoup to parse the obtained HTML, and find the first sortable table. This is the table of Largest cities that dominates the Wikipedia article.

# %%
# parse with BeautifulSoup and find the first sortable table
soup = BeautifulSoup(article, 'html.parser')
table = soup.find('table', class_='sortable')

# %% [markdown]
# We create a new Pandas dataframe to hold our cities. We will also save its nation, its population count, and its URL.

# %%
# create an empty DataFrame
cols=["City", "Province", "Population", "Area", "Density", "Income", "URL", "FlagURL"]
df_cities = pd.DataFrame(columns=cols)
df_cities['Population'].astype(int)
df_cities['Area'].astype(float)
df_cities['Density'].astype(float)
df_cities['Income'].astype(int)
# Out:
# Series([], Name: Income, dtype: int64)

# %% [markdown]
# We can now traverse through the entire table and append the required data to our dataframe

# %%
# iterate trough all the rows in the table:
for tr in table.find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue                            # skips first row with headings

    citycell = tds[0].find_all('a')
    if (len(citycell)==2):
        flagurl = "https://nl.wikipedia.org" + citycell[0]['href']
        url = "https://nl.wikipedia.org" + citycell[1]['href']
        city = citycell[1]['title']
    else:
        url = "https://nl.wikipedia.org" + citycell[0]['href']
        city = citycell[0]['title']
    
    try:
        province = tds[1].find_all('a')[1]['title'].replace('(hoofdbetekenis)','').replace('(provincie)','').replace('(Nederland)','').strip()
    except:
        province = "Geen"
        
    pop = int(re.compile(r'\[.*\]').sub("",tds[2].text).replace('(geschat)','').strip().replace('.','').replace('.',''))
    area = float(tds[3].text.strip().replace('.','').replace(',','.'))
    density = float(tds[4].text.strip().replace('.','').replace(',','.'))    
    try:    
        income = int(tds[5].text.strip().replace('.',''))   
    except ValueError:
        income = None
        
    df_cities = df_cities.append({
        'City': str(city), 
        'Province': str(province), 
        'Population': pop,
        'Area': area,
        'Density': density,
        'Income': income,
        'URL': str(url),
        'FlagURL': str(flagurl)
    }, ignore_index=True)

# %%
df_cities.drop_duplicates(keep='first', inplace=True)

# %%
print ("Shape: {}".format(df_cities.shape))
print ("There are {} unique city names".format(df_cities['City'].nunique()))
df_cities.head()
# Out:
# Shape: (383, 8)
# There are 383 unique city names
#                 City       Province Population    Area  Density Income  \
# 0        Aa en Hunze        Drenthe      25319  276.35     91.2  13400
# 1            Aalburg  Noord-Brabant      13191   50.40    257.5  12500
# 2           Aalsmeer  Noord-Holland      31584   20.58   1512.7  14700
# 3  Aalten (gemeente)     Gelderland      26943   96.57    278.7  11900
# 4      Achtkarspelen      Friesland      27897  102.61    272.7  11400
#
#                                                URL  \
# 0        https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 1            https://nl.wikipedia.org/wiki/Aalburg
# 2           https://nl.wikipedia.org/wiki/Aalsmeer
# 3  https://nl.wikipedia.org/wiki/Aalten_(gemeente)
# 4      https://nl.wikipedia.org/wiki/Achtkarspelen
#
#                                              FlagURL
# 0  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...
# 1  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...
# 2  https://nl.wikipedia.org/wiki/Bestand:Aalsmeer...
# 3  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...
# 4  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...

# %%
# Scrape an individual cities page for its coordinates
def scrape_city_coords(url):
    print(url)
    article = requests.get(url).text
    reg = re.search(r'"lat":(.*?),"lon":(.*?)}', article)
    if reg is None:
        return 0,0
    lat = float(reg.group(1))
    lon = float(reg.group(2))
    return lat,lon

# %% [markdown]
# Next we will run this function on the URLs to create two new columns

# %%
df_cities["Latitude"], df_cities["Longitude"] = zip(*df_cities["URL"].map(scrape_city_coords))
# Out:
# https://nl.wikipedia.org/wiki/Aa_en_Hunze
# https://nl.wikipedia.org/wiki/Aalburg
# https://nl.wikipedia.org/wiki/Aalsmeer
# https://nl.wikipedia.org/wiki/Aalten_(gemeente)
# https://nl.wikipedia.org/wiki/Achtkarspelen
# https://nl.wikipedia.org/wiki/Alblasserdam
# https://nl.wikipedia.org/wiki/Albrandswaard
# https://nl.wikipedia.org/wiki/Alkmaar_(gemeente)
# https://nl.wikipedia.org/wiki/Almelo
# https://nl.wikipedia.org/wiki/Almere
# https://nl.wikipedia.org/wiki/Alphen_aan_den_Rijn_(gemeente)
# https://nl.wikipedia.org/wiki/Alphen-Chaam
# https://nl.wikipedia.org/wiki/Ameland_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Amersfoort_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Amstelveen
# https://nl.wikipedia.org/wiki/Amsterdam_(gemeente)
# https://nl.wikipedia.org/wiki/Apeldoorn_(gemeente)
# https://nl.wikipedia.org/wiki/Appingedam
# https://nl.wikipedia.org/wiki/Arnhem
# https://nl.wikipedia.org/wiki/Assen
# https://nl.wikipedia.org/wiki/Asten_(gemeente)
# https://nl.wikipedia.org/wiki/Baarle-Nassau
# https://nl.wikipedia.org/wiki/Baarn
# https://nl.wikipedia.org/wiki/Barendrecht
# https://nl.wikipedia.org/wiki/Barneveld_(gemeente)
# https://nl.wikipedia.org/wiki/Bedum_(gemeente)
# https://nl.wikipedia.org/wiki/Beek_(gemeente)
# https://nl.wikipedia.org/wiki/Beemster
# https://nl.wikipedia.org/wiki/Beesel_(gemeente)
# https://nl.wikipedia.org/wiki/Berg_en_Dal_(gemeente)
# https://nl.wikipedia.org/wiki/Bergeijk_(gemeente)
# https://nl.wikipedia.org/wiki/Bergen_(Limburg,_gemeente)
# https://nl.wikipedia.org/wiki/Bergen_(Noord-Holland)
# https://nl.wikipedia.org/wiki/Bergen_op_Zoom_(gemeente)
# https://nl.wikipedia.org/wiki/Berkelland
# https://nl.wikipedia.org/wiki/Bernheze
# https://nl.wikipedia.org/wiki/Best
# https://nl.wikipedia.org/wiki/Beuningen_(Gelderland)
# https://nl.wikipedia.org/wiki/Beverwijk
# https://nl.wikipedia.org/wiki/De_Bilt_(gemeente)
# https://nl.wikipedia.org/wiki/Binnenmaas
# https://nl.wikipedia.org/wiki/Bladel_(gemeente)
# https://nl.wikipedia.org/wiki/Blaricum
# https://nl.wikipedia.org/wiki/Bloemendaal_(Noord-Holland)
# https://nl.wikipedia.org/wiki/Bonaire
# https://nl.wikipedia.org/wiki/Bodegraven-Reeuwijk
# https://nl.wikipedia.org/wiki/Boekel_(gemeente)
# https://nl.wikipedia.org/wiki/Ten_Boer
# https://nl.wikipedia.org/wiki/Borger-Odoorn
# https://nl.wikipedia.org/wiki/Borne_(Overijssel)
# https://nl.wikipedia.org/wiki/Borsele_(gemeente)
# https://nl.wikipedia.org/wiki/Boxmeer_(gemeente)
# https://nl.wikipedia.org/wiki/Boxtel_(gemeente)
# https://nl.wikipedia.org/wiki/Breda_(gemeente)
# https://nl.wikipedia.org/wiki/Brielle
# https://nl.wikipedia.org/wiki/Bronckhorst_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Brummen_(gemeente)
# https://nl.wikipedia.org/wiki/Brunssum
# https://nl.wikipedia.org/wiki/Bunnik_(gemeente)
# https://nl.wikipedia.org/wiki/Bunschoten
# https://nl.wikipedia.org/wiki/Buren_(gemeente)
# https://nl.wikipedia.org/wiki/Capelle_aan_den_IJssel
# https://nl.wikipedia.org/wiki/Castricum
# https://nl.wikipedia.org/wiki/Coevorden
# https://nl.wikipedia.org/wiki/Cranendonck
# https://nl.wikipedia.org/wiki/Cromstrijen
# https://nl.wikipedia.org/wiki/Cuijk_(gemeente)
# https://nl.wikipedia.org/wiki/Culemborg
# https://nl.wikipedia.org/wiki/Dalfsen_(gemeente)
# https://nl.wikipedia.org/wiki/Dantumadeel
# https://nl.wikipedia.org/wiki/De_Friese_Meren
# https://nl.wikipedia.org/wiki/Delft
# https://nl.wikipedia.org/wiki/Delfzijl
# https://nl.wikipedia.org/wiki/Den_Haag
# https://nl.wikipedia.org/wiki/Deurne_(Nederlandse_gemeente)
# https://nl.wikipedia.org/wiki/Deventer_(gemeente)
# https://nl.wikipedia.org/wiki/Diemen
# https://nl.wikipedia.org/wiki/Dinkelland
# https://nl.wikipedia.org/wiki/Doesburg
# https://nl.wikipedia.org/wiki/Doetinchem_(gemeente)
# https://nl.wikipedia.org/wiki/Dongen_(gemeente)
# https://nl.wikipedia.org/wiki/Dongeradeel
# https://nl.wikipedia.org/wiki/Dordrecht
# https://nl.wikipedia.org/wiki/Drechterland_(gemeente)
# https://nl.wikipedia.org/wiki/Drimmelen_(gemeente)
# https://nl.wikipedia.org/wiki/Dronten
# https://nl.wikipedia.org/wiki/Druten
# https://nl.wikipedia.org/wiki/Duiven_(gemeente)
# https://nl.wikipedia.org/wiki/Echt-Susteren
# https://nl.wikipedia.org/wiki/Edam-Volendam
# https://nl.wikipedia.org/wiki/Ede_(gemeente)
# https://nl.wikipedia.org/wiki/Eemnes
# https://nl.wikipedia.org/wiki/Eemsmond
# https://nl.wikipedia.org/wiki/Eersel_(gemeente)
# https://nl.wikipedia.org/wiki/Eijsden-Margraten
# https://nl.wikipedia.org/wiki/Eindhoven
# https://nl.wikipedia.org/wiki/Elburg_(gemeente)
# https://nl.wikipedia.org/wiki/Emmen_(gemeente)
# https://nl.wikipedia.org/wiki/Enkhuizen
# https://nl.wikipedia.org/wiki/Enschede
# https://nl.wikipedia.org/wiki/Epe_(gemeente)
# https://nl.wikipedia.org/wiki/Ermelo_(gemeente)
# https://nl.wikipedia.org/wiki/Etten-Leur
# https://nl.wikipedia.org/wiki/Ferwerderadeel
# https://nl.wikipedia.org/wiki/Geertruidenberg_(gemeente)
# https://nl.wikipedia.org/wiki/Geldermalsen_(gemeente)
# https://nl.wikipedia.org/wiki/Geldrop-Mierlo
# https://nl.wikipedia.org/wiki/Gemert-Bakel
# https://nl.wikipedia.org/wiki/Gennep_(gemeente)
# https://nl.wikipedia.org/wiki/Giessenlanden
# https://nl.wikipedia.org/wiki/Gilze_en_Rijen
# https://nl.wikipedia.org/wiki/Goeree-Overflakkee
# https://nl.wikipedia.org/wiki/Goes_(gemeente)
# https://nl.wikipedia.org/wiki/Goirle_(gemeente)
# https://nl.wikipedia.org/wiki/Gooise_Meren
# https://nl.wikipedia.org/wiki/Gorinchem
# https://nl.wikipedia.org/wiki/Gouda_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Grave_(gemeente)
# https://nl.wikipedia.org/wiki/Groningen_(gemeente)
# https://nl.wikipedia.org/wiki/Grootegast_(gemeente)
# https://nl.wikipedia.org/wiki/Gulpen-Wittem
# https://nl.wikipedia.org/wiki/Haaksbergen
# https://nl.wikipedia.org/wiki/Haaren_(gemeente)
# https://nl.wikipedia.org/wiki/Haarlem
# https://nl.wikipedia.org/wiki/Haarlemmerliede_en_Spaarnwoude
# https://nl.wikipedia.org/wiki/Haarlemmermeer
# https://nl.wikipedia.org/wiki/Halderberge
# https://nl.wikipedia.org/wiki/Hardenberg_(gemeente)
# https://nl.wikipedia.org/wiki/Harderwijk_(Gelderland)
# https://nl.wikipedia.org/wiki/Hardinxveld-Giessendam
# https://nl.wikipedia.org/wiki/Haren_(Groningen)
# https://nl.wikipedia.org/wiki/Harlingen_(gemeente)
# https://nl.wikipedia.org/wiki/Hattem
# https://nl.wikipedia.org/wiki/Heemskerk_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Heemstede_(Noord-Holland)
# https://nl.wikipedia.org/wiki/Heerde_(gemeente)
# https://nl.wikipedia.org/wiki/Heerenveen_(gemeente)
# https://nl.wikipedia.org/wiki/Heerhugowaard
# https://nl.wikipedia.org/wiki/Heerlen
# https://nl.wikipedia.org/wiki/Heeze-Leende
# https://nl.wikipedia.org/wiki/Heiloo
# https://nl.wikipedia.org/wiki/Den_Helder
# https://nl.wikipedia.org/wiki/Hellendoorn_(gemeente)
# https://nl.wikipedia.org/wiki/Hellevoetsluis
# https://nl.wikipedia.org/wiki/Helmond
# https://nl.wikipedia.org/wiki/Hendrik-Ido-Ambacht
# https://nl.wikipedia.org/wiki/Hengelo_(Overijssel)
# https://nl.wikipedia.org/wiki/%27s-Hertogenbosch_(gemeente)
# https://nl.wikipedia.org/wiki/Heumen_(gemeente)
# https://nl.wikipedia.org/wiki/Heusden_(gemeente)
# https://nl.wikipedia.org/wiki/Hillegom
# https://nl.wikipedia.org/wiki/Hilvarenbeek_(gemeente)
# https://nl.wikipedia.org/wiki/Hilversum
# https://nl.wikipedia.org/wiki/Hof_van_Twente
# https://nl.wikipedia.org/wiki/Hollands_Kroon_(gemeente)
# https://nl.wikipedia.org/wiki/Hoogeveen_(gemeente)
# https://nl.wikipedia.org/wiki/Hoorn_(Noord-Holland)
# https://nl.wikipedia.org/wiki/Horst_aan_de_Maas
# https://nl.wikipedia.org/wiki/Houten
# https://nl.wikipedia.org/wiki/Huizen
# https://nl.wikipedia.org/wiki/Hulst_(gemeente)
# https://nl.wikipedia.org/wiki/IJsselstein
# https://nl.wikipedia.org/wiki/Kaag_en_Braassem
# https://nl.wikipedia.org/wiki/Kampen_(gemeente)
# https://nl.wikipedia.org/wiki/Kapelle_(gemeente)
# https://nl.wikipedia.org/wiki/Katwijk_(Zuid-Holland)
# https://nl.wikipedia.org/wiki/Kerkrade_(gemeente)
# https://nl.wikipedia.org/wiki/Koggenland
# https://nl.wikipedia.org/wiki/Kollumerland_en_Nieuwkruisland
# https://nl.wikipedia.org/wiki/Korendijk
# https://nl.wikipedia.org/wiki/Krimpen_aan_den_IJssel
# https://nl.wikipedia.org/wiki/Krimpenerwaard_(gemeente)
# https://nl.wikipedia.org/wiki/Laarbeek_(gemeente)
# https://nl.wikipedia.org/wiki/Landerd
# https://nl.wikipedia.org/wiki/Landgraaf_(gemeente)
# https://nl.wikipedia.org/wiki/Landsmeer
# https://nl.wikipedia.org/wiki/Langedijk
# https://nl.wikipedia.org/wiki/Lansingerland
# https://nl.wikipedia.org/wiki/Laren_(Noord-Holland)
# https://nl.wikipedia.org/wiki/Leek_(Groningen)
# https://nl.wikipedia.org/wiki/Leerdam_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Leeuwarden_(gemeente)
# https://nl.wikipedia.org/wiki/Leiden_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Leiderdorp
# https://nl.wikipedia.org/wiki/Leidschendam-Voorburg
# https://nl.wikipedia.org/wiki/Lelystad
# https://nl.wikipedia.org/wiki/Leudal_(gemeente)
# https://nl.wikipedia.org/wiki/Leusden
# https://nl.wikipedia.org/wiki/Lingewaal
# https://nl.wikipedia.org/wiki/Lingewaard
# https://nl.wikipedia.org/wiki/Lisse
# https://nl.wikipedia.org/wiki/Lochem_(gemeente)
# https://nl.wikipedia.org/wiki/Loon_op_Zand_(gemeente)
# https://nl.wikipedia.org/wiki/Lopik_(gemeente)
# https://nl.wikipedia.org/wiki/Loppersum_(gemeente)
# https://nl.wikipedia.org/wiki/Losser_(gemeente)
# https://nl.wikipedia.org/wiki/Maasdriel
# https://nl.wikipedia.org/wiki/Maasgouw_(gemeente)
# https://nl.wikipedia.org/wiki/Maassluis
# https://nl.wikipedia.org/wiki/Maastricht
# https://nl.wikipedia.org/wiki/De_Marne
# https://nl.wikipedia.org/wiki/Marum_(gemeente)
# https://nl.wikipedia.org/wiki/Medemblik_(gemeente)
# https://nl.wikipedia.org/wiki/Meerssen_(gemeente)
# https://nl.wikipedia.org/wiki/Meierijstad
# https://nl.wikipedia.org/wiki/Meppel
# https://nl.wikipedia.org/wiki/Middelburg_(gemeente)
# https://nl.wikipedia.org/wiki/Midden-Delfland
# https://nl.wikipedia.org/wiki/Midden-Drenthe
# https://nl.wikipedia.org/wiki/Midden-Groningen_(gemeente)
# https://nl.wikipedia.org/wiki/Mill_en_Sint_Hubert
# https://nl.wikipedia.org/wiki/Moerdijk_(gemeente)
# https://nl.wikipedia.org/wiki/Molenwaard
# https://nl.wikipedia.org/wiki/Montferland_(gemeente)
# https://nl.wikipedia.org/wiki/Montfoort
# https://nl.wikipedia.org/wiki/Mook_en_Middelaar
# https://nl.wikipedia.org/wiki/Neder-Betuwe_(gemeente)
# https://nl.wikipedia.org/wiki/Nederweert_(gemeente)
# https://nl.wikipedia.org/wiki/Neerijnen_(gemeente)
# https://nl.wikipedia.org/wiki/Nieuwegein
# https://nl.wikipedia.org/wiki/Nieuwkoop
# https://nl.wikipedia.org/wiki/Nijkerk_(gemeente)
# https://nl.wikipedia.org/wiki/Nijmegen_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Nissewaard
# https://nl.wikipedia.org/wiki/Noord-Beveland
# https://nl.wikipedia.org/wiki/Noordenveld_(gemeente)
# https://nl.wikipedia.org/wiki/Noordoostpolder
# https://nl.wikipedia.org/wiki/Noordwijk_(Zuid-Holland)
# https://nl.wikipedia.org/wiki/Noordwijkerhout
# https://nl.wikipedia.org/wiki/Nuenen,_Gerwen_en_Nederwetten
# https://nl.wikipedia.org/wiki/Nunspeet_(gemeente)
# https://nl.wikipedia.org/wiki/Nuth_(gemeente)
# https://nl.wikipedia.org/wiki/Oegstgeest
# https://nl.wikipedia.org/wiki/Oirschot_(gemeente)
# https://nl.wikipedia.org/wiki/Oisterwijk_(gemeente)
# https://nl.wikipedia.org/wiki/Oldambt_(gemeente)
# https://nl.wikipedia.org/wiki/Oldebroek_(gemeente)
# https://nl.wikipedia.org/wiki/Oldenzaal
# https://nl.wikipedia.org/wiki/Olst-Wijhe
# https://nl.wikipedia.org/wiki/Ommen_(gemeente)
# https://nl.wikipedia.org/wiki/Onderbanken
# https://nl.wikipedia.org/wiki/Oosterhout_(gemeente)
# https://nl.wikipedia.org/wiki/Oost_Gelre
# https://nl.wikipedia.org/wiki/Ooststellingwerf
# https://nl.wikipedia.org/wiki/Oostzaan
# https://nl.wikipedia.org/wiki/Opmeer
# https://nl.wikipedia.org/wiki/Opsterland
# https://nl.wikipedia.org/wiki/Oss_(gemeente)
# https://nl.wikipedia.org/wiki/Oud-Beijerland
# https://nl.wikipedia.org/wiki/Oude_IJsselstreek
# https://nl.wikipedia.org/wiki/Ouder-Amstel
# https://nl.wikipedia.org/wiki/Oudewater
# https://nl.wikipedia.org/wiki/Overbetuwe
# https://nl.wikipedia.org/wiki/Papendrecht
# https://nl.wikipedia.org/wiki/Peel_en_Maas
# https://nl.wikipedia.org/wiki/Pekela
# https://nl.wikipedia.org/wiki/Purmerend
# https://nl.wikipedia.org/wiki/Putten_(gemeente)
# https://nl.wikipedia.org/wiki/Pijnacker-Nootdorp
# https://nl.wikipedia.org/wiki/Raalte_(gemeente)
# https://nl.wikipedia.org/wiki/Reimerswaal_(gemeente)
# https://nl.wikipedia.org/wiki/Renkum_(gemeente)
# https://nl.wikipedia.org/wiki/Renswoude
# https://nl.wikipedia.org/wiki/Reusel-De_Mierden
# https://nl.wikipedia.org/wiki/Rheden_(gemeente)
# https://nl.wikipedia.org/wiki/Rhenen
# https://nl.wikipedia.org/wiki/Ridderkerk
# https://nl.wikipedia.org/wiki/Rijssen-Holten
# https://nl.wikipedia.org/wiki/Rijswijk_(Zuid-Holland)
# https://nl.wikipedia.org/wiki/Roerdalen
# https://nl.wikipedia.org/wiki/Roermond_(gemeente)
# https://nl.wikipedia.org/wiki/De_Ronde_Venen
# https://nl.wikipedia.org/wiki/Roosendaal_(gemeente)
# https://nl.wikipedia.org/wiki/Rotterdam_(gemeente)
# https://nl.wikipedia.org/wiki/Rozendaal
# https://nl.wikipedia.org/wiki/Rucphen_(gemeente)
# https://nl.wikipedia.org/wiki/Saba
# https://nl.wikipedia.org/wiki/Schagen_(gemeente)
# https://nl.wikipedia.org/wiki/Scherpenzeel_(Gelderland)
# https://nl.wikipedia.org/wiki/Schiedam
# https://nl.wikipedia.org/wiki/Schiermonnikoog
# https://nl.wikipedia.org/wiki/Schinnen_(gemeente)
# https://nl.wikipedia.org/wiki/Schouwen-Duiveland
# https://nl.wikipedia.org/wiki/Simpelveld_(gemeente)
# https://nl.wikipedia.org/wiki/Sint_Anthonis_(gemeente)
# https://nl.wikipedia.org/wiki/Sint_Eustatius
# https://nl.wikipedia.org/wiki/Sint-Michielsgestel_(gemeente)
# https://nl.wikipedia.org/wiki/Sittard-Geleen
# https://nl.wikipedia.org/wiki/Sliedrecht
# https://nl.wikipedia.org/wiki/Sluis_(gemeente)
# https://nl.wikipedia.org/wiki/Smallingerland
# https://nl.wikipedia.org/wiki/Soest_(Nederland)
# https://nl.wikipedia.org/wiki/Someren_(gemeente)
# https://nl.wikipedia.org/wiki/Son_en_Breugel
# https://nl.wikipedia.org/wiki/Stadskanaal_(gemeente)
# https://nl.wikipedia.org/wiki/Staphorst_(gemeente)
# https://nl.wikipedia.org/wiki/Stede_Broec
# https://nl.wikipedia.org/wiki/Steenbergen_(gemeente)
# https://nl.wikipedia.org/wiki/Steenwijkerland
# https://nl.wikipedia.org/wiki/Stein_(gemeente)
# https://nl.wikipedia.org/wiki/Stichtse_Vecht
# https://nl.wikipedia.org/wiki/Strijen
# https://nl.wikipedia.org/wiki/S%C3%BAdwest-Frysl%C3%A2n
# https://nl.wikipedia.org/wiki/Terneuzen_(gemeente)
# https://nl.wikipedia.org/wiki/Terschelling
# https://nl.wikipedia.org/wiki/Texel
# https://nl.wikipedia.org/wiki/Teylingen_(gemeente)
# https://nl.wikipedia.org/wiki/Tholen_(gemeente)
# https://nl.wikipedia.org/wiki/Tiel
# https://nl.wikipedia.org/wiki/Tietjerksteradeel
# https://nl.wikipedia.org/wiki/Tilburg_(gemeente)
# https://nl.wikipedia.org/wiki/Tubbergen_(gemeente)
# https://nl.wikipedia.org/wiki/Twenterand
# https://nl.wikipedia.org/wiki/Tynaarlo_(gemeente)
# https://nl.wikipedia.org/wiki/Uden_(gemeente)
# https://nl.wikipedia.org/wiki/Uitgeest
# https://nl.wikipedia.org/wiki/Uithoorn
# https://nl.wikipedia.org/wiki/Urk
# https://nl.wikipedia.org/wiki/Utrecht_(stad)
# https://nl.wikipedia.org/wiki/Utrechtse_Heuvelrug_(gemeente)
# https://nl.wikipedia.org/wiki/Vaals_(gemeente)
# https://nl.wikipedia.org/wiki/Valkenburg_aan_de_Geul
# https://nl.wikipedia.org/wiki/Valkenswaard_(gemeente)
# https://nl.wikipedia.org/wiki/Veendam_(gemeente)
# https://nl.wikipedia.org/wiki/Veenendaal
# https://nl.wikipedia.org/wiki/Veere_(gemeente)
# https://nl.wikipedia.org/wiki/Veldhoven_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Velsen
# https://nl.wikipedia.org/wiki/Venlo_(gemeente)
# https://nl.wikipedia.org/wiki/Venray_(gemeente)
# https://nl.wikipedia.org/wiki/Vianen_(Utrecht)
# https://nl.wikipedia.org/wiki/Vlaardingen
# https://nl.wikipedia.org/wiki/Vlieland_(hoofdbetekenis)
# https://nl.wikipedia.org/wiki/Vlissingen
# https://nl.wikipedia.org/wiki/Voerendaal_(gemeente)
# https://nl.wikipedia.org/wiki/Voorschoten
# https://nl.wikipedia.org/wiki/Voorst_(gemeente)
# https://nl.wikipedia.org/wiki/Vught_(gemeente)
# https://nl.wikipedia.org/wiki/Waadhoeke
# https://nl.wikipedia.org/wiki/Waalre_(gemeente)
# https://nl.wikipedia.org/wiki/Waalwijk_(gemeente)
# https://nl.wikipedia.org/wiki/Waddinxveen
# https://nl.wikipedia.org/wiki/Wageningen_(Nederland)
# https://nl.wikipedia.org/wiki/Wassenaar_(gemeente)
# https://nl.wikipedia.org/wiki/Waterland_(gemeente)
# https://nl.wikipedia.org/wiki/Weert_(gemeente)
# https://nl.wikipedia.org/wiki/Weesp
# https://nl.wikipedia.org/wiki/Werkendam_(gemeente)
# https://nl.wikipedia.org/wiki/Westland_(gemeente)
# https://nl.wikipedia.org/wiki/West_Maas_en_Waal
# https://nl.wikipedia.org/wiki/Westerveld_(gemeente)
# https://nl.wikipedia.org/wiki/Westervoort
# https://nl.wikipedia.org/wiki/Westerwolde_(gemeente)
# https://nl.wikipedia.org/wiki/Weststellingwerf
# https://nl.wikipedia.org/wiki/Westvoorne
# https://nl.wikipedia.org/wiki/Wierden
# https://nl.wikipedia.org/wiki/Wijchen_(gemeente)
# https://nl.wikipedia.org/wiki/Wijdemeren
# https://nl.wikipedia.org/wiki/Wijk_bij_Duurstede
# https://nl.wikipedia.org/wiki/Winsum_(gemeente)
# https://nl.wikipedia.org/wiki/Winterswijk_(gemeente)
# https://nl.wikipedia.org/wiki/Woensdrecht_(gemeente)
# https://nl.wikipedia.org/wiki/Woerden
# https://nl.wikipedia.org/wiki/De_Wolden
# https://nl.wikipedia.org/wiki/Wormerland
# https://nl.wikipedia.org/wiki/Woudenberg
# https://nl.wikipedia.org/wiki/Woudrichem_(gemeente)
# https://nl.wikipedia.org/wiki/Zaanstad
# https://nl.wikipedia.org/wiki/Zaltbommel_(gemeente)
# https://nl.wikipedia.org/wiki/Zandvoort
# https://nl.wikipedia.org/wiki/Zederik
# https://nl.wikipedia.org/wiki/Zeewolde
# https://nl.wikipedia.org/wiki/Zeist
# https://nl.wikipedia.org/wiki/Zevenaar_(gemeente)
# https://nl.wikipedia.org/wiki/Zoetermeer
# https://nl.wikipedia.org/wiki/Zoeterwoude
# https://nl.wikipedia.org/wiki/Zuidhorn_(gemeente)
# https://nl.wikipedia.org/wiki/Zuidplas_(gemeente)
# https://nl.wikipedia.org/wiki/Zundert_(gemeente)
# https://nl.wikipedia.org/wiki/Zutphen_(gemeente)
# https://nl.wikipedia.org/wiki/Zwartewaterland
# https://nl.wikipedia.org/wiki/Zwijndrecht_(Nederland)
# https://nl.wikipedia.org/wiki/Zwolle_(hoofdbetekenis)

# %%
df_cities.shape
# Out:
# (383, 10)

# %% [markdown]
# remove anything without coordinates

# %%
df_cities = df_cities[df_cities['Latitude'] != 0]
df_cities = df_cities[df_cities['Longitude'] != 0]
df_cities.dropna(axis=0, subset=['Latitude', 'Longitude'])
df_cities.shape
# Out:
# (377, 10)

# %%
df_cities.head()
# Out:
#                 City       Province Population    Area  Density Income  \
# 0        Aa en Hunze        Drenthe      25319  276.35     91.2  13400
# 1            Aalburg  Noord-Brabant      13191   50.40    257.5  12500
# 2           Aalsmeer  Noord-Holland      31584   20.58   1512.7  14700
# 3  Aalten (gemeente)     Gelderland      26943   96.57    278.7  11900
# 4      Achtkarspelen      Friesland      27897  102.61    272.7  11400
#
#                                                URL  \
# 0        https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 1            https://nl.wikipedia.org/wiki/Aalburg
# 2           https://nl.wikipedia.org/wiki/Aalsmeer
# 3  https://nl.wikipedia.org/wiki/Aalten_(gemeente)
# 4      https://nl.wikipedia.org/wiki/Achtkarspelen
#
#                                              FlagURL   Latitude  Longitude
# 0  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...  53.000000   6.750000
# 1  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...  51.752500   5.131944
# 2  https://nl.wikipedia.org/wiki/Bestand:Aalsmeer...  52.263889   4.762500
# 3  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...  51.925000   6.580833
# 4  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...  53.216667   6.133333

# %% [markdown]
# ## 4. Getting more information from Foursquare

# %% [markdown]
# This information is needed to connect with Foursquare API

# %%
CLIENT_ID = 'YPBVFDUZOP1M24BKCWGXIYZ3RFACOE3V35WSFY4DSCMRU44L' # your Foursquare ID
CLIENT_SECRET = 'VYHYTBSRIZBPYAOCP5ZEFV3YM4C40YEQCQWCUO4NC1JTPNJM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# We will ask Foursquare for the top picks in every city, then store its name, location and main category.

# %%
def getRecommendedVenues(cities, latitudes, longitudes):
    
    venues_list=[]
    for city, lat, lon in zip(cities, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&section=topPicks&client_id={}&client_secret={}&v={}&ll={},{}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lon,
            100)
            
        # make the GET request
        response = requests.get(url)
        if response.status_code == requests.codes.ok:
            results = response.json()["response"]['groups'][0]['items']
        else:
            print ("status was:" + str(response.status_code))
            print ("could not scrape " + url)
            break
        
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            city,
            v['venue']['name'], 
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])


    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City',
                  'Venue',
                  'Venue ID',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Now, actually run the above function for every city.

# %%
df_venues = getRecommendedVenues(df_cities['City'], df_cities['Latitude'], df_cities['Longitude'])
print("all done")
# Out:
# all done

# %%
print ("Found {} venues for {} different cities".format(df_venues.shape[0], len(df_venues.groupby('City'))))
df_venues.head()
# Out:
# Found 16339 venues for 377 different cities
#           City                     Venue                  Venue ID  \
# 0  Aa en Hunze            Hof van Saksen  4be09a4f4c55b651217beab7
# 1  Aa en Hunze       Robin Hood Ribhouse  4b85585df964a5200b5831e3
# 2  Aa en Hunze  Zwembad | Hof van Saksen  4c3b2cb3d94dc9b63156ffe7
# 3  Aa en Hunze     Restaurant Hofsteenge  4bebf67ba9900f47505b1840
# 4  Aa en Hunze            Hunebedcentrum  4c2f2541ac0ab71368b41b1e
#
#    Venue Latitude  Venue Longitude  Venue Category
# 0       52.966395         6.674498          Resort
# 1       52.957088         6.788140      Restaurant
# 2       52.965237         6.676055            Pool
# 3       52.935398         6.672966            Café
# 4       52.931130         6.797330  History Museum

# %% [markdown]
# That's looking pretty awesome. Now let's prevent more scraping by saving the dataframe to a file.

# %% [markdown]
# ## 5. Joining the dataframe

# %%
df_joined = pd.merge(df_venues, df_cities, on='City')
print ("The joined dataframe contains {} different cities".format(len(df_joined.groupby('City'))))
df_joined.head()
# Out:
# The joined dataframe contains 377 different cities
#           City                     Venue                  Venue ID  \
# 0  Aa en Hunze            Hof van Saksen  4be09a4f4c55b651217beab7
# 1  Aa en Hunze       Robin Hood Ribhouse  4b85585df964a5200b5831e3
# 2  Aa en Hunze  Zwembad | Hof van Saksen  4c3b2cb3d94dc9b63156ffe7
# 3  Aa en Hunze     Restaurant Hofsteenge  4bebf67ba9900f47505b1840
# 4  Aa en Hunze            Hunebedcentrum  4c2f2541ac0ab71368b41b1e
#
#    Venue Latitude  Venue Longitude  Venue Category Province Population  \
# 0       52.966395         6.674498          Resort  Drenthe      25319
# 1       52.957088         6.788140      Restaurant  Drenthe      25319
# 2       52.965237         6.676055            Pool  Drenthe      25319
# 3       52.935398         6.672966            Café  Drenthe      25319
# 4       52.931130         6.797330  History Museum  Drenthe      25319
#
#      Area  Density Income                                        URL  \
# 0  276.35     91.2  13400  https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 1  276.35     91.2  13400  https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 2  276.35     91.2  13400  https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 3  276.35     91.2  13400  https://nl.wikipedia.org/wiki/Aa_en_Hunze
# 4  276.35     91.2  13400  https://nl.wikipedia.org/wiki/Aa_en_Hunze
#
#                                              FlagURL  Latitude  Longitude
# 0  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...      53.0       6.75
# 1  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...      53.0       6.75
# 2  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...      53.0       6.75
# 3  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...      53.0       6.75
# 4  https://nl.wikipedia.org/wiki/Bestand:Flag_of_...      53.0       6.75

# %% [markdown]
# ## 6. Saving the dataframes

# %% [markdown]
# We export the dataframes so we don't have to scrape again.
# First as CSV, as this is a very generic format.
# Secondly as pickle, since this is a quick way to import the dataframe again.

# %%
# export both dataframes as CSV
df_cities.to_csv('cities.csv')
df_venues.to_csv('venues.csv')
df_joined.to_csv('joined.cvs')

# %%
# export both dataframe as pickles
df_cities.to_pickle('cities.pickle')
df_venues.to_pickle('venues.pickle')
df_joined.to_pickle('joined.pickle')
